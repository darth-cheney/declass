# %%
import os
import random

import pandas as pd
import matplotlib.pylab as plt

from collections import Counter
from sklearn.svm import OneClassSVM
from sklearn.covariance import EmpiricalCovariance, MinCovDet
from numpy import linalg
from sklearn.ensemble import RandomForestClassifier
from sklearn import preprocessing


from rosetta.text import text_processors, filefilter, gensim_helpers,\
    streamers, vw_helpers
# Out:
# /Users/danielkrasner/anaconda/lib/python2.7/site-packages/scipy/lib/_util.py:35: DeprecationWarning: Module scipy.linalg.blas.fblas is deprecated, use scipy.linalg.blas instead
#   DeprecationWarning)
# /Users/danielkrasner/anaconda/lib/python2.7/site-packages/scipy/lib/_util.py:35: DeprecationWarning: Module scipy.linalg.blas.fblas is deprecated, use scipy.linalg.blas instead
#   DeprecationWarning)
# /Users/danielkrasner/anaconda/lib/python2.7/site-packages/scipy/lib/_util.py:35: DeprecationWarning: Module scipy.linalg.blas.fblas is deprecated, use scipy.linalg.blas instead
#   DeprecationWarning)
# /Users/danielkrasner/anaconda/lib/python2.7/site-packages/scipy/lib/_util.py:35: DeprecationWarning: Module scipy.linalg.blas.fblas is deprecated, use scipy.linalg.blas instead
#   DeprecationWarning)
# /Users/danielkrasner/anaconda/lib/python2.7/site-packages/scipy/lib/_util.py:35: DeprecationWarning: Module scipy.linalg.blas.fblas is deprecated, use scipy.linalg.blas instead
#   DeprecationWarning)

# %%
pd.set_option('max_rows', 100)

# %%
# Every time you change the source code you need to reload it
reload(text_processors)
reload(filefilter)
reload(streamers)
reload(vw_helpers)
# Out:
# <module 'rosetta.text.vw_helpers' from '/Users/danielkrasner/anaconda/lib/python2.7/site-packages/rosetta/text/vw_helpers.pyc'>

# %%
# Set paths         
# I use environment variables to set my base paths
DATA = os.environ['DATA']                                                                                                                                     
MYDATA = os.path.join(DATA, 'declass')
CABLES = os.path.join(MYDATA, 'cables-full-01') 
RAW = os.path.join(CABLES, 'raw')                                                         
PROCESSED = os.path.join(CABLES, 'processed')
SPARSE = os.path.join(PROCESSED, 'sparse')
META = os.path.join(CABLES,'meta')
PLOTS = os.path.join(CABLES, 'plots')

# You only need to set these paths below...any way you can
metafile_path = os.path.join(META, 'meta.csv')
text_base_path = os.path.join(RAW, 'bodyfiles')  # Read files made with the "nofoot" option
sfile_path = os.path.join(SPARSE, 'cables-full.vw')
filtered_sfile_path = os.path.join(PROCESSED, 'cables-full-filtered.vw')
sff_path = os.path.join(PROCESSED, 'sff.pkl')

# %%
meta = pd.read_csv(metafile_path, sep='|').set_index('doc_id').drop('doc_nbr', axis=1)  # doc_nbr == doc_id
meta = meta[meta.has_text == 1]
# Out:
# /Users/danielkrasner/anaconda/lib/python2.7/site-packages/pandas/io/parsers.py:1050: DtypeWarning: Columns (22) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = self._reader.read(nrows)

# %%
#drop duplicated from meta
dupes = [i for i,c in Counter(meta.index).items() if c >1]
meta = meta.drop(dupes)

# %%
meta.shape
# Out:
# (1119239, 25)

# %%
# There were some duplicate indices....figure out what is going on later
meta['index'] = meta.index
meta = meta.drop_duplicates(cols='index')
meta = meta.drop('index', axis=1)

# %%
meta['from__to'] = meta.msgfrom + '__' + meta.msgto
meta['other'] = meta.from__to.str.replace('STATE', '').str.replace('__', '')

# %%
meta.shape
# Out:
# (1119239, 27)

# %% [markdown]
# #Create vw file for corpus

# %%
#make sure you use the right sfile_path
print sfile_path
# Out:
# /Users/danielkrasner/DATA_master/prod/declass/cables-full-01/processed/sparse/cables-full.vw

# %%
my_tokenizer = text_processors.TokenizerBasic()
stream = streamers.TextFileStreamer(text_base_path=text_base_path, tokenizer=my_tokenizer)
#stream = streamers.TextFileStreamer(path_list=lda_paths, tokenizer=my_tokenizer)
stream.to_vw(sfile_path, n_jobs=-1, raise_on_bad_id=False)

# %%
### somewhere here run (stick with 5 passes or so...) and make sure you use the right path!
# rm -f *cache
#vw --lda 80 --cache_file doc_tokens.cache --passes 5 -p prediction.dat --readable_model topics.dat --bit_precision 20 --lda_D 10000 --lda_rho 0.1 --lda_alpha 1 ../cables-full.vw

# %%
formatter = text_processors.VWFormatter()
sff = text_processors.SFileFilter(formatter)
sff.load_sfile(sfile_path)

# %%
#sff.compactify()
#sff.save(PROCESSED + '/sff_sub.pkl')
# Out:
# Compactification done.  self.bit_precision_required = 18
# collisions = 0, vocab_size = 155948
# All collisions resolved

# %%
#sff.to_frame().sort_index(by='doc_fraction', ascending=False).head(4)
# Out:
#           doc_freq  token_score  doc_fraction
# token
# info         36701        67988      0.793432
# page         36700        85012      0.793411
# fm           36698        41095      0.793367
# secstate     36594        41458      0.791119
#
# [4 rows x 3 columns]

# %%
#sff = text_processors.SFileFilter.load(PROCESSED + '/sff_sub.pkl')
#print sff.vocab_size
# Out:
# 155948

# %%
sff.filter_extremes(doc_freq_min=100, doc_fraction_max=0.7)
sff.compactify()
sff.save(PROCESSED + '/sff.pkl')
# Out:
# /Users/danielkrasner/anaconda/lib/python2.7/site-packages/pandas/compat/scipy.py:68: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   score = values[idx]
# /Users/danielkrasner/anaconda/lib/python2.7/site-packages/pandas/compat/scipy.py:68: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   score = values[idx]
# Removed 1008097/1043145 tokens
# Compactification done.  self.bit_precision_required = 16
# collisions = 0, vocab_size = 35048
# All collisions resolved

# %% [markdown]
# ## Get LDA results

# %%
lda = vw_helpers.LDAResults(PROCESSED + '/topics.dat', 
                            PROCESSED + '/prediction.dat', PROCESSED + '/sff.pkl')

# %%
##save the lda.pr_topic_g_doc.T data frame for later use
lda.pr_topic_g_doc.T.to_csv(os.path.join(PROCESSED, 'pr_topic_g_doc.csv'))

# %%
topic_words = lda.pr_token_g_topic.loc[:,'topic_12'].order(ascending=False).index[:10]
lda.sfile_frame.loc[topic_words]
# Out:
#              doc_freq  token_score  doc_fraction
# token
# nicosia         13827        27090      0.012349
# neua              329          574      0.000294
# hostage           740          902      0.000661
# gyorgy            135          183      0.000121
# snyder            453          699      0.000405
# heichler          246          301      0.000220
# smun              329          703      0.000294
# jacqueline        263          350      0.000235
# internecine       153          159      0.000137
# thus            50483        62412      0.045088
#
# [10 rows x 3 columns]

# %%
# Miklos topic number
lda.pr_token_g_topic.loc['miklos'].order(ascending=False).head(2)
# Out:
# topic_75    0.000028
# topic_73    0.000028
# Name: miklos, dtype: float64

# %%
# Tehran topic number
lda.pr_token_g_topic.loc['tehran'].order(ascending=False).head(2)
# Out:
# topic_75    0.000028
# topic_73    0.000028
# Name: tehran, dtype: float64

# %%
lda.pr_doc_g_topic.loc['1976ANKARA07970'].order(ascending=False).head(4)
# Out:
# topic_78    0.000002
# topic_75    0.000000
# topic_73    0.000000
# topic_72    0.000000
# Name: 1976ANKARA07970, dtype: float64

# %%
lda.print_topics(20)
# Out:
# ========== Printing top 20 tokens in every topic==========
# ------------------------------
# Topic name: topic_00.  P[topic_00] = 0.0107
#                    topic_00  doc_freq
# token
# nicosia            0.000042     13827
# neua               0.000040       329
# hostage            0.000039       740
# gyorgy             0.000039       135
# snyder             0.000038       453
# heichler           0.000038       246
# smun               0.000037       329
# jacqueline         0.000037       263
# internecine        0.000037       153
# thus               0.000036     50483
# crumbling          0.000036       109
# sindermann         0.000036       106
# gmc                0.000035       140
# reactions          0.000035      7812
# commercialization  0.000035       157
# mahe               0.000035       147
# zimbabwean         0.000034       242
# finalize           0.000034      1536
# curtains           0.000034       148
# toyo               0.000034       258
#
# ------------------------------
# Topic name: topic_01.  P[topic_01] = 0.0107
#                    topic_01  doc_freq
# token
# nicosia            0.000042     13827
# neua               0.000040       329
# hostage            0.000039       740
# gyorgy             0.000039       135
# snyder             0.000038       453
# heichler           0.000038       246
# smun               0.000037       329
# jacqueline         0.000037       263
# internecine        0.000037       153
# thus               0.000036     50483
# crumbling          0.000036       109
# sindermann         0.000036       106
# gmc                0.000035       140
# reactions          0.000035      7812
# commercialization  0.000035       157
# mahe               0.000035       147
# zimbabwean         0.000034       242
# finalize           0.000034      1536
# curtains           0.000034       148
# toyo               0.000034       258
#
# ------------------------------
# Topic name: topic_02.  P[topic_02] = 0.0107
#                    topic_02  doc_freq
# token
# nicosia            0.000042     13827
# neua               0.000040       329
# hostage            0.000039       740
# gyorgy             0.000039       135
# snyder             0.000038       453
# heichler           0.000038       246
# smun               0.000037       329
# jacqueline         0.000037       263
# internecine        0.000037       153
# thus               0.000036     50483
# crumbling          0.000036       109
# sindermann         0.000036       106
# gmc                0.000035       140
# reactions          0.000035      7812
# commercialization  0.000035       157
# mahe               0.000035       147
# zimbabwean         0.000034       242
# finalize           0.000034      1536
# curtains           0.000034       148
# toyo               0.000034       258
#
# ------------------------------
# Topic name: topic_03.  P[topic_03] = 0.0107
#                    topic_03  doc_freq
# token
# nicosia            0.000042     13827
# neua               0.000040       329
# hostage            0.000039       740
# gyorgy             0.000039       135
# snyder             0.000038       453
# heichler           0.000038       246
# smun               0.000037       329
# jacqueline         0.000037       263
# internecine        0.000037       153
# thus               0.000036     50483
# crumbling          0.000036       109
# sindermann         0.000036       106
# gmc                0.000035       140
# reactions          0.000035      7812
# commercialization  0.000035       157
# mahe               0.000035       147
# zimbabwean         0.000034       242
# finalize           0.000034      1536
# curtains           0.000034       148
# toyo               0.000034       258
#
# ------------------------------
# Topic name: topic_04.  P[topic_04] = 0.0107
#                    topic_04  doc_freq
# token
# nicosia            0.000042     13827
# neua               0.000040       329
# hostage            0.000039       740
# gyorgy             0.000039       135
# snyder             0.000038       453
# heichler           0.000038       246
# smun               0.000037       329
# jacqueline         0.000037       263
# internecine        0.000037       153
# thus               0.000036     50483
# crumbling          0.000036       109
# sindermann         0.000036       106
# gmc                0.000035       140
# reactions          0.000035      7812
# commercialization  0.000035       157
# mahe               0.000035       147
# zimbabwean         0.000034       242
# finalize           0.000034      1536
# curtains           0.000034       148
# toyo               0.000034       258
#
# ------------------------------
# Topic name: topic_05.  P[topic_05] = 0.0107
#               topic_05  doc_freq
# token
# jacqueline    0.000080       263
# resistence    0.000062       224
# neua          0.000061       329
# nicosia       0.000042     13827
# washington's  0.000041      1564
# measurement   0.000040      1002
# financier     0.000039       170
# columns       0.000039       844
# inclination   0.000039      1301
# hostage       0.000039       740
# gyorgy        0.000038       135
# snyder        0.000038       453
# heichler      0.000038       246
# ideally       0.000037       988
# schweid       0.000037       345
# illegal       0.000037      5971
# smun          0.000037       329
# internecine   0.000037       153
# thus          0.000036     50483
# crumbling     0.000036       109
#
# ------------------------------
# Topic name: topic_06.  P[topic_06] = 0.0107
#                    topic_06  doc_freq
# token
# nicosia            0.000042     13827
# neua               0.000040       329
# hostage            0.000039       740
# gyorgy             0.000039       135
# snyder             0.000038       453
# heichler           0.000038       246
# smun               0.000037       329
# jacqueline         0.000037       263
# internecine        0.000037       153
# thus               0.000036     50483
# crumbling          0.000036       109
# sindermann         0.000036       106
# gmc                0.000035       140
# reactions          0.000035      7812
# commercialization  0.000035       157
# mahe               0.000035       147
# zimbabwean         0.000034       242
# finalize           0.000034      1536
# curtains           0.000034       148
# toyo               0.000034       258
#
# ------------------------------
# Topic name: topic_07.  P[topic_07] = 0.0137
#                topic_07  doc_freq
# token
# mias           0.213655       289
# congestion     0.000055      1082
# nicosia        0.000048     13827
# sindermann     0.000037       106
# snyder         0.000032       453
# neua           0.000031       329
# ford           0.000030     14052
# belives        0.000030       298
# explicitly     0.000030      3020
# meany          0.000030       549
# columns        0.000030       844
# gyorgy         0.000030       135
# hostage        0.000029       740
# wednesday      0.000029     12089
# acquaintances  0.000029       244
# heichler       0.000029       246
# smun           0.000028       329
# jacqueline     0.000028       263
# internecine    0.000028       153
# thus           0.000028     50483
#
# ------------------------------
# Topic name: topic_08.  P[topic_08] = 0.0107
#                    topic_08  doc_freq
# token
# nicosia            0.000042     13827
# neua               0.000040       329
# hostage            0.000039       740
# gyorgy             0.000039       135
# snyder             0.000038       453
# heichler           0.000038       246
# smun               0.000037       329
# jacqueline         0.000037       263
# internecine        0.000037       153
# thus               0.000036     50483
# crumbling          0.000036       109
# sindermann         0.000036       106
# gmc                0.000035       140
# reactions          0.000035      7812
# commercialization  0.000035       157
# mahe               0.000035       147
# zimbabwean         0.000034       242
# finalize           0.000034      1536
# curtains           0.000034       148
# toyo               0.000034       258
#
# ------------------------------
# Topic name: topic_09.  P[topic_09] = 0.0107
#                    topic_09  doc_freq
# token
# nicosia            0.000042     13827
# neua               0.000040       329
# hostage            0.000039       740
# gyorgy             0.000039       135
# snyder             0.000038       453
# heichler           0.000038       246
# smun               0.000037       329
# jacqueline         0.000037       263
# internecine        0.000037       153
# thus               0.000036     50483
# crumbling          0.000036       109
# sindermann         0.000036       106
# gmc                0.000035       140
# reactions          0.000035      7812
# commercialization  0.000035       157
# mahe               0.000035       147
# zimbabwean         0.000034       242
# finalize           0.000034      1536
# curtains           0.000034       148
# toyo               0.000034       258
#
# ------------------------------
# Topic name: topic_10.  P[topic_10] = 0.0107
#                topic_10  doc_freq
# token
# reactions      0.000058      7812
# militants      0.000054       766
# nicosia        0.000042     13827
# neua           0.000040       329
# hostage        0.000039       740
# gyorgy         0.000038       135
# force's        0.000038       156
# snyder         0.000038       453
# conveyors      0.000038       131
# heichler       0.000038       246
# acquaintances  0.000037       244
# refuting       0.000037       244
# smun           0.000037       329
# fall           0.000037     18799
# jacqueline     0.000037       263
# internecine    0.000036       153
# else's         0.000036       126
# thus           0.000036     50483
# unwritten      0.000036       145
# crumbling      0.000036       109
#
# ------------------------------
# Topic name: topic_11.  P[topic_11] = 0.0107
#                    topic_11  doc_freq
# token
# nicosia            0.000042     13827
# neua               0.000040       329
# hostage            0.000039       740
# gyorgy             0.000039       135
# snyder             0.000038       453
# heichler           0.000038       246
# smun               0.000037       329
# jacqueline         0.000037       263
# internecine        0.000037       153
# thus               0.000036     50483
# crumbling          0.000036       109
# sindermann         0.000036       106
# gmc                0.000035       140
# reactions          0.000035      7812
# commercialization  0.000035       157
# mahe               0.000035       147
# zimbabwean         0.000034       242
# finalize           0.000034      1536
# curtains           0.000034       148
# toyo               0.000034       258
#
# ------------------------------
# Topic name: topic_12.  P[topic_12] = 0.0107
#                    topic_12  doc_freq
# token
# nicosia            0.000042     13827
# neua               0.000040       329
# hostage            0.000039       740
# gyorgy             0.000039       135
# snyder             0.000038       453
# heichler           0.000038       246
# smun               0.000037       329
# jacqueline         0.000037       263
# internecine        0.000037       153
# thus               0.000036     50483
# crumbling          0.000036       109
# sindermann         0.000036       106
# gmc                0.000035       140
# reactions          0.000035      7812
# commercialization  0.000035       157
# mahe               0.000035       147
# zimbabwean         0.000034       242
# finalize           0.000034      1536
# curtains           0.000034       148
# toyo               0.000034       258
#
# ------------------------------
# Topic name: topic_13.  P[topic_13] = 0.0107
#                    topic_13  doc_freq
# token
# nicosia            0.000042     13827
# neua               0.000040       329
# hostage            0.000039       740
# gyorgy             0.000039       135
# snyder             0.000038       453
# heichler           0.000038       246
# smun               0.000037       329
# jacqueline         0.000037       263
# internecine        0.000037       153
# thus               0.000036     50483
# crumbling          0.000036       109
# sindermann         0.000036       106
# gmc                0.000035       140
# reactions          0.000035      7812
# commercialization  0.000035       157
# mahe               0.000035       147
# zimbabwean         0.000034       242
# finalize           0.000034      1536
# curtains           0.000034       148
# toyo               0.000034       258
#
# ------------------------------
# Topic name: topic_14.  P[topic_14] = 0.0107
#                    topic_14  doc_freq
# token
# nicosia            0.000042     13827
# neua               0.000040       329
# hostage            0.000039       740
# gyorgy             0.000039       135
# snyder             0.000038       453
# heichler           0.000038       246
# smun               0.000037       329
# jacqueline         0.000037       263
# internecine        0.000037       153
# thus               0.000036     50483
# crumbling          0.000036       109
# sindermann         0.000036       106
# gmc                0.000035       140
# reactions          0.000035      7812
# commercialization  0.000035       157
# mahe               0.000035       147
# zimbabwean         0.000034       242
# finalize           0.000034      1536
# curtains           0.000034       148
# toyo               0.000034       258
#
# ------------------------------
# Topic name: topic_15.  P[topic_15] = 0.0107
#                    topic_15  doc_freq
# token
# nicosia            0.000042     13827
# neua               0.000040       329
# hostage            0.000039       740
# gyorgy             0.000039       135
# snyder             0.000038       453
# heichler           0.000038       246
# smun               0.000037       329
# jacqueline         0.000037       263
# internecine        0.000037       153
# thus               0.000036     50483
# crumbling          0.000036       109
# sindermann         0.000036       106
# gmc                0.000035       140
# reactions          0.000035      7812
# commercialization  0.000035       157
# mahe               0.000035       147
# zimbabwean         0.000034       242
# finalize           0.000034      1536
# curtains           0.000034       148
# toyo               0.000034       258
#
# ------------------------------
# Topic name: topic_16.  P[topic_16] = 0.0107
#                    topic_16  doc_freq
# token
# nicosia            0.000042     13827
# neua               0.000040       329
# hostage            0.000039       740
# gyorgy             0.000039       135
# snyder             0.000038       453
# heichler           0.000038       246
# smun               0.000037       329
# jacqueline         0.000037       263
# internecine        0.000037       153
# thus               0.000036     50483
# crumbling          0.000036       109
# sindermann         0.000036       106
# gmc                0.000035       140
# reactions          0.000035      7812
# commercialization  0.000035       157
# mahe               0.000035       147
# zimbabwean         0.000034       242
# finalize           0.000034      1536
# curtains           0.000034       148
# toyo               0.000034       258
#
# ------------------------------
# Topic name: topic_17.  P[topic_17] = 0.0107
#                    topic_17  doc_freq
# token
# nicosia            0.000042     13827
# neua               0.000040       329
# hostage            0.000039       740
# gyorgy             0.000039       135
# snyder             0.000038       453
# heichler           0.000038       246
# smun               0.000037       329
# jacqueline         0.000037       263
# internecine        0.000037       153
# thus               0.000036     50483
# crumbling          0.000036       109
# sindermann         0.000036       106
# gmc                0.000035       140
# reactions          0.000035      7812
# commercialization  0.000035       157
# mahe               0.000035       147
# zimbabwean         0.000034       242
# finalize           0.000034      1536
# curtains           0.000034       148
# toyo               0.000034       258
#
# ------------------------------
# Topic name: topic_18.  P[topic_18] = 0.0107
#                    topic_18  doc_freq
# token
# nicosia            0.000042     13827
# neua               0.000040       329
# hostage            0.000039       740
# gyorgy             0.000039       135
# snyder             0.000038       453
# heichler           0.000038       246
# smun               0.000037       329
# jacqueline         0.000037       263
# internecine        0.000037       153
# thus               0.000036     50483
# crumbling          0.000036       109
# sindermann         0.000036       106
# gmc                0.000035       140
# reactions          0.000035      7812
# commercialization  0.000035       157
# mahe               0.000035       147
# zimbabwean         0.000034       242
# finalize           0.000034      1536
# curtains           0.000034       148
# toyo               0.000034       258
#
# ------------------------------
# Topic name: topic_19.  P[topic_19] = 0.0107
#                    topic_19  doc_freq
# token
# nicosia            0.000042     13827
# neua               0.000040       329
# hostage            0.000039       740
# gyorgy             0.000039       135
# snyder             0.000038       453
# heichler           0.000038       246
# smun               0.000037       329
# jacqueline         0.000037       263
# internecine        0.000037       153
# thus               0.000036     50483
# crumbling          0.000036       109
# sindermann         0.000036       106
# gmc                0.000035       140
# reactions          0.000035      7812
# commercialization  0.000035       157
# mahe               0.000035       147
# zimbabwean         0.000034       242
# finalize           0.000034      1536
# curtains           0.000034       148
# toyo               0.000034       258
#
# ------------------------------
# Topic name: topic_20.  P[topic_20] = 0.0107
#                    topic_20  doc_freq
# token
# nicosia            0.000042     13827
# neua               0.000040       329
# hostage            0.000039       740
# gyorgy             0.000039       135
# snyder             0.000038       453
# heichler           0.000038       246
# acquaintances      0.000038       244
# smun               0.000037       329
# jacqueline         0.000037       263
# internecine        0.000037       153
# thus               0.000036     50483
# crumbling          0.000036       109
# discount           0.000036      2690
# sindermann         0.000036       106
# gmc                0.000035       140
# reactions          0.000035      7812
# financier          0.000035       170
# commercialization  0.000035       157
# mahe               0.000035       147
# gamble             0.000035       526
#
# ------------------------------
# Topic name: topic_21.  P[topic_21] = 0.0107
#                    topic_21  doc_freq
# token
# nicosia            0.000042     13827
# neua               0.000040       329
# hostage            0.000039       740
# gyorgy             0.000039       135
# snyder             0.000038       453
# heichler           0.000038       246
# smun               0.000037       329
# jacqueline         0.000037       263
# internecine        0.000037       153
# thus               0.000036     50483
# crumbling          0.000036       109
# sindermann         0.000036       106
# gmc                0.000035       140
# reactions          0.000035      7812
# commercialization  0.000035       157
# mahe               0.000035       147
# zimbabwean         0.000034       242
# finalize           0.000034      1536
# curtains           0.000034       148
# toyo               0.000034       258
#
# ------------------------------
# Topic name: topic_22.  P[topic_22] = 0.0107
#                    topic_22  doc_freq
# token
# nicosia            0.000042     13827
# neua               0.000040       329
# hostage            0.000039       740
# gyorgy             0.000039       135
# snyder             0.000038       453
# heichler           0.000038       246
# smun               0.000037       329
# jacqueline         0.000037       263
# internecine        0.000037       153
# thus               0.000036     50483
# crumbling          0.000036       109
# sindermann         0.000036       106
# gmc                0.000035       140
# reactions          0.000035      7812
# commercialization  0.000035       157
# mahe               0.000035       147
# zimbabwean         0.000034       242
# finalize           0.000034      1536
# curtains           0.000034       148
# toyo               0.000034       258
#
# ------------------------------
# Topic name: topic_23.  P[topic_23] = 0.0107
#                    topic_23  doc_freq
# token
# nicosia            0.000042     13827
# neua               0.000040       329
# hostage            0.000039       740
# gyorgy             0.000039       135
# snyder             0.000038       453
# heichler           0.000038       246
# smun               0.000037       329
# jacqueline         0.000037       263
# internecine        0.000037       153
# thus               0.000036     50483
# crumbling          0.000036       109
# sindermann         0.000036       106
# gmc                0.000035       140
# reactions          0.000035      7812
# commercialization  0.000035       157
# mahe               0.000035       147
# zimbabwean         0.000034       242
# finalize           0.000034      1536
# curtains           0.000034       148
# toyo               0.000034       258
#
# ------------------------------
# Topic name: topic_24.  P[topic_24] = 0.0107
#                    topic_24  doc_freq
# token
# nicosia            0.000042     13827
# neua               0.000040       329
# hostage            0.000039       740
# gyorgy             0.000039       135
# snyder             0.000038       453
# heichler           0.000038       246
# smun               0.000037       329
# jacqueline         0.000037       263
# internecine        0.000037       153
# thus               0.000036     50483
# crumbling          0.000036       109
# sindermann         0.000036       106
# gmc                0.000035       140
# reactions          0.000035      7812
# commercialization  0.000035       157
# mahe               0.000035       147
# zimbabwean         0.000034       242
# finalize           0.000034      1536
# curtains           0.000034       148
# toyo               0.000034       258
#
# ------------------------------
# Topic name: topic_25.  P[topic_25] = 0.0107
#                    topic_25  doc_freq
# token
# nicosia            0.000042     13827
# neua               0.000040       329
# hostage            0.000039       740
# gyorgy             0.000039       135
# snyder             0.000038       453
# heichler           0.000038       246
# smun               0.000037       329
# jacqueline         0.000037       263
# internecine        0.000037       153
# thus               0.000036     50483
# crumbling          0.000036       109
# sindermann         0.000036       106
# gmc                0.000035       140
# reactions          0.000035      7812
# commercialization  0.000035       157
# mahe               0.000035       147
# zimbabwean         0.000034       242
# finalize           0.000034      1536
# curtains           0.000034       148
# toyo               0.000034       258
#
# ------------------------------
# Topic name: topic_26.  P[topic_26] = 0.0107
#                    topic_26  doc_freq
# token
# nicosia            0.000042     13827
# neua               0.000040       329
# hostage            0.000039       740
# gyorgy             0.000039       135
# snyder             0.000038       453
# heichler           0.000038       246
# smun               0.000037       329
# jacqueline         0.000037       263
# internecine        0.000037       153
# thus               0.000036     50483
# crumbling          0.000036       109
# sindermann         0.000036       106
# gmc                0.000035       140
# reactions          0.000035      7812
# commercialization  0.000035       157
# mahe               0.000035       147
# zimbabwean         0.000034       242
# finalize           0.000034      1536
# curtains           0.000034       148
# toyo               0.000034       258
#
# ------------------------------
# Topic name: topic_27.  P[topic_27] = 0.0107
#                    topic_27  doc_freq
# token
# nicosia            0.000042     13827
# neua               0.000040       329
# hostage            0.000039       740
# gyorgy             0.000039       135
# snyder             0.000038       453
# heichler           0.000038       246
# smun               0.000037       329
# jacqueline         0.000037       263
# internecine        0.000037       153
# thus               0.000036     50483
# crumbling          0.000036       109
# sindermann         0.000036       106
# gmc                0.000035       140
# reactions          0.000035      7812
# commercialization  0.000035       157
# mahe               0.000035       147
# zimbabwean         0.000034       242
# finalize           0.000034      1536
# curtains           0.000034       148
# toyo               0.000034       258
#
# ------------------------------
# Topic name: topic_28.  P[topic_28] = 0.0107
#                    topic_28  doc_freq
# token
# nicosia            0.000042     13827
# neua               0.000040       329
# hostage            0.000039       740
# gyorgy             0.000039       135
# snyder             0.000038       453
# heichler           0.000038       246
# smun               0.000037       329
# jacqueline         0.000037       263
# internecine        0.000037       153
# thus               0.000036     50483
# crumbling          0.000036       109
# sindermann         0.000036       106
# gmc                0.000035       140
# reactions          0.000035      7812
# commercialization  0.000035       157
# mahe               0.000035       147
# zimbabwean         0.000034       242
# finalize           0.000034      1536
# curtains           0.000034       148
# toyo               0.000034       258
#
# ------------------------------
# Topic name: topic_29.  P[topic_29] = 0.0107
#                    topic_29  doc_freq
# token
# nicosia            0.000042     13827
# neua               0.000040       329
# hostage            0.000039       740
# gyorgy             0.000039       135
# snyder             0.000038       453
# heichler           0.000038       246
# smun               0.000037       329
# jacqueline         0.000037       263
# internecine        0.000037       153
# thus               0.000036     50483
# crumbling          0.000036       109
# sindermann         0.000036       106
# gmc                0.000035       140
# reactions          0.000035      7812
# commercialization  0.000035       157
# mahe               0.000035       147
# zimbabwean         0.000034       242
# finalize           0.000034      1536
# curtains           0.000034       148
# toyo               0.000034       258
#
# ------------------------------
# Topic name: topic_30.  P[topic_30] = 0.0107
#                    topic_30  doc_freq
# token
# nicosia            0.000042     13827
# neua               0.000040       329
# hostage            0.000039       740
# gyorgy             0.000039       135
# snyder             0.000038       453
# heichler           0.000038       246
# smun               0.000037       329
# jacqueline         0.000037       263
# internecine        0.000037       153
# thus               0.000036     50483
# crumbling          0.000036       109
# sindermann         0.000036       106
# gmc                0.000035       140
# reactions          0.000035      7812
# commercialization  0.000035       157
# mahe               0.000035       147
# zimbabwean         0.000034       242
# finalize           0.000034      1536
# curtains           0.000034       148
# toyo               0.000034       258
#
# ------------------------------
# Topic name: topic_31.  P[topic_31] = 0.0107
#                    topic_31  doc_freq
# token
# nicosia            0.000042     13827
# neua               0.000040       329
# hostage            0.000039       740
# gyorgy             0.000039       135
# snyder             0.000038       453
# heichler           0.000038       246
# smun               0.000037       329
# jacqueline         0.000037       263
# internecine        0.000037       153
# thus               0.000036     50483
# crumbling          0.000036       109
# sindermann         0.000036       106
# gmc                0.000035       140
# reactions          0.000035      7812
# commercialization  0.000035       157
# mahe               0.000035       147
# zimbabwean         0.000034       242
# finalize           0.000034      1536
# curtains           0.000034       148
# toyo               0.000034       258
#
# ------------------------------
# Topic name: topic_32.  P[topic_32] = 0.0107
#                    topic_32  doc_freq
# token
# nicosia            0.000042     13827
# neua               0.000040       329
# hostage            0.000039       740
# gyorgy             0.000039       135
# snyder             0.000038       453
# heichler           0.000038       246
# smun               0.000037       329
# jacqueline         0.000037       263
# internecine        0.000037       153
# thus               0.000036     50483
# crumbling          0.000036       109
# sindermann         0.000036       106
# gmc                0.000035       140
# reactions          0.000035      7812
# commercialization  0.000035       157
# mahe               0.000035       147
# zimbabwean         0.000034       242
# finalize           0.000034      1536
# curtains           0.000034       148
# toyo               0.000034       258
#
# ------------------------------
# Topic name: topic_33.  P[topic_33] = 0.0107
#                    topic_33  doc_freq
# token
# nicosia            0.000042     13827
# neua               0.000040       329
# hostage            0.000039       740
# gyorgy             0.000039       135
# snyder             0.000038       453
# heichler           0.000038       246
# smun               0.000037       329
# jacqueline         0.000037       263
# internecine        0.000037       153
# thus               0.000036     50483
# crumbling          0.000036       109
# sindermann         0.000036       106
# gmc                0.000035       140
# reactions          0.000035      7812
# commercialization  0.000035       157
# mahe               0.000035       147
# zimbabwean         0.000034       242
# finalize           0.000034      1536
# curtains           0.000034       148
# toyo               0.000034       258
#
# ------------------------------
# Topic name: topic_34.  P[topic_34] = 0.0107
#                    topic_34  doc_freq
# token
# nicosia            0.000042     13827
# neua               0.000040       329
# hostage            0.000039       740
# gyorgy             0.000039       135
# snyder             0.000038       453
# heichler           0.000038       246
# smun               0.000037       329
# jacqueline         0.000037       263
# internecine        0.000037       153
# thus               0.000036     50483
# crumbling          0.000036       109
# sindermann         0.000036       106
# gmc                0.000035       140
# reactions          0.000035      7812
# commercialization  0.000035       157
# mahe               0.000035       147
# zimbabwean         0.000034       242
# finalize           0.000034      1536
# curtains           0.000034       148
# toyo               0.000034       258
#
# ------------------------------
# Topic name: topic_35.  P[topic_35] = 0.0107
#                    topic_35  doc_freq
# token
# nicosia            0.000042     13827
# neua               0.000040       329
# hostage            0.000039       740
# gyorgy             0.000039       135
# snyder             0.000038       453
# heichler           0.000038       246
# smun               0.000037       329
# jacqueline         0.000037       263
# internecine        0.000037       153
# thus               0.000036     50483
# crumbling          0.000036       109
# sindermann         0.000036       106
# gmc                0.000035       140
# reactions          0.000035      7812
# commercialization  0.000035       157
# mahe               0.000035       147
# zimbabwean         0.000034       242
# finalize           0.000034      1536
# curtains           0.000034       148
# toyo               0.000034       258
#
# ------------------------------
# Topic name: topic_36.  P[topic_36] = 0.0107
#                    topic_36  doc_freq
# token
# nicosia            0.000042     13827
# neua               0.000040       329
# hostage            0.000039       740
# gyorgy             0.000039       135
# snyder             0.000038       453
# heichler           0.000038       246
# smun               0.000037       329
# jacqueline         0.000037       263
# internecine        0.000037       153
# thus               0.000036     50483
# crumbling          0.000036       109
# sindermann         0.000036       106
# gmc                0.000035       140
# reactions          0.000035      7812
# commercialization  0.000035       157
# mahe               0.000035       147
# zimbabwean         0.000034       242
# finalize           0.000034      1536
# curtains           0.000034       148
# toyo               0.000034       258
#
# ------------------------------
# Topic name: topic_37.  P[topic_37] = 0.0107
#                    topic_37  doc_freq
# token
# nicosia            0.000042     13827
# neua               0.000040       329
# hostage            0.000039       740
# gyorgy             0.000039       135
# snyder             0.000038       453
# heichler           0.000038       246
# smun               0.000037       329
# jacqueline         0.000037       263
# internecine        0.000037       153
# thus               0.000036     50483
# crumbling          0.000036       109
# sindermann         0.000036       106
# gmc                0.000035       140
# reactions          0.000035      7812
# commercialization  0.000035       157
# mahe               0.000035       147
# zimbabwean         0.000034       242
# finalize           0.000034      1536
# curtains           0.000034       148
# toyo               0.000034       258
#
# ------------------------------
# Topic name: topic_38.  P[topic_38] = 0.0107
#                    topic_38  doc_freq
# token
# nicosia            0.000042     13827
# neua               0.000040       329
# hostage            0.000039       740
# gyorgy             0.000039       135
# snyder             0.000038       453
# heichler           0.000038       246
# smun               0.000037       329
# jacqueline         0.000037       263
# internecine        0.000037       153
# thus               0.000036     50483
# crumbling          0.000036       109
# sindermann         0.000036       106
# gmc                0.000035       140
# reactions          0.000035      7812
# commercialization  0.000035       157
# mahe               0.000035       147
# zimbabwean         0.000034       242
# finalize           0.000034      1536
# curtains           0.000034       148
# toyo               0.000034       258
#
# ------------------------------
# Topic name: topic_39.  P[topic_39] = 0.0107
#                    topic_39  doc_freq
# token
# nicosia            0.000042     13827
# neua               0.000040       329
# hostage            0.000039       740
# gyorgy             0.000039       135
# snyder             0.000038       453
# heichler           0.000038       246
# smun               0.000037       329
# jacqueline         0.000037       263
# internecine        0.000037       153
# thus               0.000036     50483
# crumbling          0.000036       109
# sindermann         0.000036       106
# gmc                0.000035       140
# reactions          0.000035      7812
# commercialization  0.000035       157
# mahe               0.000035       147
# zimbabwean         0.000034       242
# finalize           0.000034      1536
# curtains           0.000034       148
# toyo               0.000034       258
#
# ------------------------------
# Topic name: topic_40.  P[topic_40] = 0.0107
#                    topic_40  doc_freq
# token
# nicosia            0.000042     13827
# neua               0.000040       329
# hostage            0.000039       740
# gyorgy             0.000039       135
# snyder             0.000038       453
# heichler           0.000038       246
# smun               0.000037       329
# jacqueline         0.000037       263
# internecine        0.000037       153
# thus               0.000036     50483
# crumbling          0.000036       109
# sindermann         0.000036       106
# gmc                0.000035       140
# reactions          0.000035      7812
# commercialization  0.000035       157
# mahe               0.000035       147
# zimbabwean         0.000034       242
# finalize           0.000034      1536
# curtains           0.000034       148
# toyo               0.000034       258
#
# ------------------------------
# Topic name: topic_41.  P[topic_41] = 0.0107
#                    topic_41  doc_freq
# token
# nicosia            0.000042     13827
# neua               0.000040       329
# hostage            0.000039       740
# gyorgy             0.000039       135
# snyder             0.000038       453
# heichler           0.000038       246
# smun               0.000037       329
# jacqueline         0.000037       263
# internecine        0.000037       153
# thus               0.000036     50483
# crumbling          0.000036       109
# sindermann         0.000036       106
# gmc                0.000035       140
# reactions          0.000035      7812
# commercialization  0.000035       157
# mahe               0.000035       147
# zimbabwean         0.000034       242
# finalize           0.000034      1536
# curtains           0.000034       148
# toyo               0.000034       258
#
# ------------------------------
# Topic name: topic_42.  P[topic_42] = 0.0107
#                    topic_42  doc_freq
# token
# nicosia            0.000042     13827
# neua               0.000040       329
# hostage            0.000039       740
# gyorgy             0.000039       135
# snyder             0.000038       453
# heichler           0.000038       246
# smun               0.000037       329
# jacqueline         0.000037       263
# internecine        0.000037       153
# thus               0.000036     50483
# crumbling          0.000036       109
# sindermann         0.000036       106
# gmc                0.000035       140
# reactions          0.000035      7812
# commercialization  0.000035       157
# mahe               0.000035       147
# zimbabwean         0.000034       242
# finalize           0.000034      1536
# curtains           0.000034       148
# toyo               0.000034       258
#
# ------------------------------
# Topic name: topic_43.  P[topic_43] = 0.0107
#                    topic_43  doc_freq
# token
# nicosia            0.000042     13827
# neua               0.000040       329
# hostage            0.000039       740
# gyorgy             0.000039       135
# snyder             0.000038       453
# heichler           0.000038       246
# smun               0.000037       329
# jacqueline         0.000037       263
# internecine        0.000037       153
# thus               0.000036     50483
# crumbling          0.000036       109
# sindermann         0.000036       106
# gmc                0.000035       140
# reactions          0.000035      7812
# commercialization  0.000035       157
# mahe               0.000035       147
# zimbabwean         0.000034       242
# finalize           0.000034      1536
# curtains           0.000034       148
# toyo               0.000034       258
#
# ------------------------------
# Topic name: topic_44.  P[topic_44] = 0.0107
#                    topic_44  doc_freq
# token
# nicosia            0.000042     13827
# neua               0.000040       329
# hostage            0.000039       740
# gyorgy             0.000039       135
# snyder             0.000038       453
# heichler           0.000038       246
# smun               0.000037       329
# jacqueline         0.000037       263
# internecine        0.000037       153
# thus               0.000036     50483
# crumbling          0.000036       109
# sindermann         0.000036       106
# gmc                0.000035       140
# reactions          0.000035      7812
# commercialization  0.000035       157
# mahe               0.000035       147
# zimbabwean         0.000034       242
# finalize           0.000034      1536
# curtains           0.000034       148
# toyo               0.000034       258
#
# ------------------------------
# Topic name: topic_45.  P[topic_45] = 0.0107
#                    topic_45  doc_freq
# token
# nicosia            0.000042     13827
# neua               0.000040       329
# hostage            0.000039       740
# gyorgy             0.000039       135
# snyder             0.000038       453
# heichler           0.000038       246
# smun               0.000037       329
# jacqueline         0.000037       263
# internecine        0.000037       153
# thus               0.000036     50483
# crumbling          0.000036       109
# sindermann         0.000036       106
# gmc                0.000035       140
# reactions          0.000035      7812
# commercialization  0.000035       157
# mahe               0.000035       147
# zimbabwean         0.000034       242
# finalize           0.000034      1536
# curtains           0.000034       148
# toyo               0.000034       258
#
# ------------------------------
# Topic name: topic_46.  P[topic_46] = 0.0107
#                    topic_46  doc_freq
# token
# nicosia            0.000042     13827
# neua               0.000040       329
# hostage            0.000039       740
# gyorgy             0.000039       135
# snyder             0.000038       453
# heichler           0.000038       246
# smun               0.000037       329
# jacqueline         0.000037       263
# internecine        0.000037       153
# thus               0.000036     50483
# crumbling          0.000036       109
# sindermann         0.000036       106
# gmc                0.000035       140
# reactions          0.000035      7812
# commercialization  0.000035       157
# mahe               0.000035       147
# zimbabwean         0.000034       242
# finalize           0.000034      1536
# curtains           0.000034       148
# toyo               0.000034       258
#
# ------------------------------
# Topic name: topic_47.  P[topic_47] = 0.0107
#                    topic_47  doc_freq
# token
# nicosia            0.000042     13827
# neua               0.000040       329
# hostage            0.000039       740
# gyorgy             0.000039       135
# snyder             0.000038       453
# heichler           0.000038       246
# smun               0.000037       329
# jacqueline         0.000037       263
# internecine        0.000037       153
# thus               0.000036     50483
# crumbling          0.000036       109
# sindermann         0.000036       106
# gmc                0.000035       140
# reactions          0.000035      7812
# commercialization  0.000035       157
# mahe               0.000035       147
# zimbabwean         0.000034       242
# finalize           0.000034      1536
# curtains           0.000034       148
# toyo               0.000034       258
#
# ------------------------------
# Topic name: topic_48.  P[topic_48] = 0.0107
#                    topic_48  doc_freq
# token
# nicosia            0.000042     13827
# neua               0.000040       329
# hostage            0.000039       740
# gyorgy             0.000039       135
# snyder             0.000038       453
# heichler           0.000038       246
# smun               0.000037       329
# jacqueline         0.000037       263
# internecine        0.000037       153
# thus               0.000036     50483
# crumbling          0.000036       109
# sindermann         0.000036       106
# gmc                0.000035       140
# reactions          0.000035      7812
# commercialization  0.000035       157
# mahe               0.000035       147
# zimbabwean         0.000034       242
# finalize           0.000034      1536
# curtains           0.000034       148
# toyo               0.000034       258
#
# ------------------------------
# Topic name: topic_49.  P[topic_49] = 0.0107
#                    topic_49  doc_freq
# token
# nicosia            0.000042     13827
# neua               0.000040       329
# hostage            0.000039       740
# gyorgy             0.000039       135
# snyder             0.000038       453
# heichler           0.000038       246
# smun               0.000037       329
# jacqueline         0.000037       263
# internecine        0.000037       153
# thus               0.000036     50483
# crumbling          0.000036       109
# sindermann         0.000036       106
# gmc                0.000035       140
# reactions          0.000035      7812
# commercialization  0.000035       157
# mahe               0.000035       147
# zimbabwean         0.000034       242
# finalize           0.000034      1536
# curtains           0.000034       148
# toyo               0.000034       258
#
# ------------------------------
# Topic name: topic_50.  P[topic_50] = 0.0107
#                    topic_50  doc_freq
# token
# nicosia            0.000042     13827
# neua               0.000040       329
# hostage            0.000039       740
# gyorgy             0.000039       135
# snyder             0.000038       453
# heichler           0.000038       246
# smun               0.000037       329
# jacqueline         0.000037       263
# internecine        0.000037       153
# thus               0.000036     50483
# crumbling          0.000036       109
# sindermann         0.000036       106
# gmc                0.000035       140
# reactions          0.000035      7812
# commercialization  0.000035       157
# mahe               0.000035       147
# zimbabwean         0.000034       242
# finalize           0.000034      1536
# curtains           0.000034       148
# toyo               0.000034       258
#
# ------------------------------
# Topic name: topic_51.  P[topic_51] = 0.0107
#                    topic_51  doc_freq
# token
# nicosia            0.000042     13827
# neua               0.000040       329
# hostage            0.000039       740
# gyorgy             0.000039       135
# snyder             0.000038       453
# heichler           0.000038       246
# smun               0.000037       329
# jacqueline         0.000037       263
# internecine        0.000037       153
# thus               0.000036     50483
# crumbling          0.000036       109
# sindermann         0.000036       106
# gmc                0.000035       140
# reactions          0.000035      7812
# commercialization  0.000035       157
# mahe               0.000035       147
# zimbabwean         0.000034       242
# finalize           0.000034      1536
# curtains           0.000034       148
# toyo               0.000034       258
#
# ------------------------------
# Topic name: topic_52.  P[topic_52] = 0.0107
#                    topic_52  doc_freq
# token
# nicosia            0.000042     13827
# neua               0.000040       329
# hostage            0.000039       740
# gyorgy             0.000039       135
# snyder             0.000038       453
# heichler           0.000038       246
# smun               0.000037       329
# jacqueline         0.000037       263
# internecine        0.000037       153
# thus               0.000036     50483
# crumbling          0.000036       109
# sindermann         0.000036       106
# gmc                0.000035       140
# reactions          0.000035      7812
# commercialization  0.000035       157
# mahe               0.000035       147
# zimbabwean         0.000034       242
# ...
# smun               0.000037       329
# jacqueline         0.000037       263
# internecine        0.000037       153
# thus               0.000036     50483
# crumbling          0.000036       109
# sindermann         0.000036       106
# gmc                0.000035       140
# reactions          0.000035      7812
# commercialization  0.000035       157
# mahe               0.000035       147
# zimbabwean         0.000034       242
# finalize           0.000034      1536
# curtains           0.000034       148
# toyo               0.000034       258
#
# ------------------------------
# Topic name: topic_63.  P[topic_63] = 0.0107
#                    topic_63  doc_freq
# token
# nicosia            0.000042     13827
# neua               0.000040       329
# hostage            0.000039       740
# gyorgy             0.000039       135
# snyder             0.000038       453
# heichler           0.000038       246
# smun               0.000037       329
# jacqueline         0.000037       263
# internecine        0.000037       153
# thus               0.000036     50483
# crumbling          0.000036       109
# sindermann         0.000036       106
# gmc                0.000035       140
# reactions          0.000035      7812
# commercialization  0.000035       157
# mahe               0.000035       147
# zimbabwean         0.000034       242
# finalize           0.000034      1536
# curtains           0.000034       148
# toyo               0.000034       258
#
# ------------------------------
# Topic name: topic_64.  P[topic_64] = 0.0107
#                    topic_64  doc_freq
# token
# nicosia            0.000042     13827
# neua               0.000040       329
# hostage            0.000039       740
# gyorgy             0.000039       135
# snyder             0.000038       453
# heichler           0.000038       246
# smun               0.000037       329
# jacqueline         0.000037       263
# internecine        0.000037       153
# thus               0.000036     50483
# crumbling          0.000036       109
# sindermann         0.000036       106
# gmc                0.000035       140
# reactions          0.000035      7812
# commercialization  0.000035       157
# mahe               0.000035       147
# zimbabwean         0.000034       242
# finalize           0.000034      1536
# curtains           0.000034       148
# toyo               0.000034       258
#
# ------------------------------
# Topic name: topic_65.  P[topic_65] = 0.0107
#                    topic_65  doc_freq
# token
# nicosia            0.000042     13827
# neua               0.000040       329
# hostage            0.000039       740
# gyorgy             0.000039       135
# snyder             0.000038       453
# heichler           0.000038       246
# smun               0.000037       329
# jacqueline         0.000037       263
# internecine        0.000037       153
# thus               0.000036     50483
# crumbling          0.000036       109
# sindermann         0.000036       106
# gmc                0.000035       140
# reactions          0.000035      7812
# commercialization  0.000035       157
# mahe               0.000035       147
# zimbabwean         0.000034       242
# finalize           0.000034      1536
# curtains           0.000034       148
# toyo               0.000034       258
#
# ------------------------------
# Topic name: topic_66.  P[topic_66] = 0.0107
#                    topic_66  doc_freq
# token
# nicosia            0.000042     13827
# neua               0.000040       329
# hostage            0.000039       740
# gyorgy             0.000039       135
# snyder             0.000038       453
# heichler           0.000038       246
# smun               0.000037       329
# jacqueline         0.000037       263
# internecine        0.000037       153
# thus               0.000036     50483
# crumbling          0.000036       109
# sindermann         0.000036       106
# gmc                0.000035       140
# reactions          0.000035      7812
# commercialization  0.000035       157
# mahe               0.000035       147
# zimbabwean         0.000034       242
# finalize           0.000034      1536
# curtains           0.000034       148
# toyo               0.000034       258
#
# ------------------------------
# Topic name: topic_67.  P[topic_67] = 0.0107
#                    topic_67  doc_freq
# token
# nicosia            0.000042     13827
# neua               0.000040       329
# hostage            0.000039       740
# gyorgy             0.000039       135
# snyder             0.000038       453
# heichler           0.000038       246
# smun               0.000037       329
# jacqueline         0.000037       263
# internecine        0.000037       153
# thus               0.000036     50483
# crumbling          0.000036       109
# sindermann         0.000036       106
# gmc                0.000035       140
# reactions          0.000035      7812
# commercialization  0.000035       157
# mahe               0.000035       147
# zimbabwean         0.000034       242
# finalize           0.000034      1536
# curtains           0.000034       148
# toyo               0.000034       258
#
# ------------------------------
# Topic name: topic_68.  P[topic_68] = 0.0107
#                    topic_68  doc_freq
# token
# nicosia            0.000042     13827
# neua               0.000040       329
# hostage            0.000039       740
# gyorgy             0.000039       135
# snyder             0.000038       453
# heichler           0.000038       246
# smun               0.000037       329
# jacqueline         0.000037       263
# internecine        0.000037       153
# thus               0.000036     50483
# crumbling          0.000036       109
# sindermann         0.000036       106
# gmc                0.000035       140
# reactions          0.000035      7812
# commercialization  0.000035       157
# mahe               0.000035       147
# zimbabwean         0.000034       242
# finalize           0.000034      1536
# curtains           0.000034       148
# toyo               0.000034       258
#
# ------------------------------
# Topic name: topic_69.  P[topic_69] = 0.0107
#                    topic_69  doc_freq
# token
# nicosia            0.000042     13827
# neua               0.000040       329
# hostage            0.000039       740
# gyorgy             0.000039       135
# snyder             0.000038       453
# heichler           0.000038       246
# smun               0.000037       329
# jacqueline         0.000037       263
# internecine        0.000037       153
# thus               0.000036     50483
# crumbling          0.000036       109
# sindermann         0.000036       106
# gmc                0.000035       140
# reactions          0.000035      7812
# commercialization  0.000035       157
# mahe               0.000035       147
# zimbabwean         0.000034       242
# finalize           0.000034      1536
# curtains           0.000034       148
# toyo               0.000034       258
#
# ------------------------------
# Topic name: topic_70.  P[topic_70] = 0.0107
#                    topic_70  doc_freq
# token
# nicosia            0.000042     13827
# neua               0.000040       329
# hostage            0.000039       740
# gyorgy             0.000039       135
# snyder             0.000038       453
# heichler           0.000038       246
# smun               0.000037       329
# jacqueline         0.000037       263
# internecine        0.000037       153
# thus               0.000036     50483
# crumbling          0.000036       109
# sindermann         0.000036       106
# gmc                0.000035       140
# reactions          0.000035      7812
# commercialization  0.000035       157
# mahe               0.000035       147
# zimbabwean         0.000034       242
# finalize           0.000034      1536
# curtains           0.000034       148
# toyo               0.000034       258
#
# ------------------------------
# Topic name: topic_71.  P[topic_71] = 0.0107
#                    topic_71  doc_freq
# token
# nicosia            0.000042     13827
# neua               0.000040       329
# hostage            0.000039       740
# gyorgy             0.000039       135
# snyder             0.000038       453
# heichler           0.000038       246
# smun               0.000037       329
# jacqueline         0.000037       263
# internecine        0.000037       153
# thus               0.000036     50483
# crumbling          0.000036       109
# sindermann         0.000036       106
# gmc                0.000035       140
# reactions          0.000035      7812
# commercialization  0.000035       157
# mahe               0.000035       147
# zimbabwean         0.000034       242
# finalize           0.000034      1536
# curtains           0.000034       148
# toyo               0.000034       258
#
# ------------------------------
# Topic name: topic_72.  P[topic_72] = 0.0107
#                    topic_72  doc_freq
# token
# nicosia            0.000042     13827
# neua               0.000040       329
# hostage            0.000039       740
# gyorgy             0.000039       135
# snyder             0.000038       453
# heichler           0.000038       246
# smun               0.000037       329
# jacqueline         0.000037       263
# internecine        0.000037       153
# thus               0.000036     50483
# crumbling          0.000036       109
# sindermann         0.000036       106
# gmc                0.000035       140
# reactions          0.000035      7812
# commercialization  0.000035       157
# mahe               0.000035       147
# zimbabwean         0.000034       242
# finalize           0.000034      1536
# curtains           0.000034       148
# toyo               0.000034       258
#
# ------------------------------
# Topic name: topic_73.  P[topic_73] = 0.0107
#                    topic_73  doc_freq
# token
# nicosia            0.000042     13827
# neua               0.000040       329
# hostage            0.000039       740
# gyorgy             0.000039       135
# snyder             0.000038       453
# heichler           0.000038       246
# smun               0.000037       329
# jacqueline         0.000037       263
# internecine        0.000037       153
# thus               0.000036     50483
# crumbling          0.000036       109
# sindermann         0.000036       106
# gmc                0.000035       140
# reactions          0.000035      7812
# commercialization  0.000035       157
# mahe               0.000035       147
# zimbabwean         0.000034       242
# finalize           0.000034      1536
# curtains           0.000034       148
# toyo               0.000034       258
#
# ------------------------------
# Topic name: topic_74.  P[topic_74] = 0.0107
#                    topic_74  doc_freq
# token
# nicosia            0.000042     13827
# neua               0.000040       329
# hostage            0.000039       740
# gyorgy             0.000039       135
# snyder             0.000038       453
# heichler           0.000038       246
# smun               0.000037       329
# jacqueline         0.000037       263
# internecine        0.000037       153
# thus               0.000036     50483
# crumbling          0.000036       109
# sindermann         0.000036       106
# gmc                0.000035       140
# zhukov             0.000035       167
# reactions          0.000035      7812
# commercialization  0.000035       157
# mahe               0.000035       147
# zimbabwean         0.000034       242
# finalize           0.000034      1536
# curtains           0.000034       148
#
# ------------------------------
# Topic name: topic_75.  P[topic_75] = 0.0107
#                    topic_75  doc_freq
# token
# nicosia            0.000042     13827
# neua               0.000040       329
# hostage            0.000039       740
# gyorgy             0.000039       135
# snyder             0.000038       453
# heichler           0.000038       246
# smun               0.000037       329
# jacqueline         0.000037       263
# internecine        0.000037       153
# thus               0.000036     50483
# crumbling          0.000036       109
# sindermann         0.000036       106
# gmc                0.000035       140
# reactions          0.000035      7812
# commercialization  0.000035       157
# mahe               0.000035       147
# zimbabwean         0.000034       242
# finalize           0.000034      1536
# curtains           0.000034       148
# toyo               0.000034       258
#
# ------------------------------
# Topic name: topic_76.  P[topic_76] = 0.0107
#                    topic_76  doc_freq
# token
# nicosia            0.000042     13827
# neua               0.000040       329
# hostage            0.000039       740
# gyorgy             0.000039       135
# snyder             0.000038       453
# heichler           0.000038       246
# smun               0.000037       329
# jacqueline         0.000037       263
# internecine        0.000037       153
# thus               0.000036     50483
# crumbling          0.000036       109
# sindermann         0.000036       106
# gmc                0.000035       140
# reactions          0.000035      7812
# commercialization  0.000035       157
# mahe               0.000035       147
# zimbabwean         0.000034       242
# finalize           0.000034      1536
# curtains           0.000034       148
# toyo               0.000034       258
#
# ------------------------------
# Topic name: topic_77.  P[topic_77] = 0.0107
#                    topic_77  doc_freq
# token
# nicosia            0.000042     13827
# neua               0.000040       329
# hostage            0.000039       740
# gyorgy             0.000039       135
# snyder             0.000038       453
# heichler           0.000038       246
# smun               0.000037       329
# jacqueline         0.000037       263
# internecine        0.000037       153
# thus               0.000036     50483
# crumbling          0.000036       109
# sindermann         0.000036       106
# gmc                0.000035       140
# reactions          0.000035      7812
# commercialization  0.000035       157
# mahe               0.000035       147
# zimbabwean         0.000034       242
# finalize           0.000034      1536
# curtains           0.000034       148
# toyo               0.000034       258
#
# ------------------------------
# Topic name: topic_78.  P[topic_78] = 0.1492
#                 topic_78  doc_freq
# token
# phongsavan      0.172822       171
# cohesiveness    0.058770       213
# project         0.036297     62069
# seoul's         0.024008       207
# daniel          0.020052      3792
# fois            0.017255       118
# tapline         0.016933       173
# togolese        0.016306       616
# cas             0.015232       391
# nassau          0.013781      4729
# astonishment    0.011614       233
# abetted         0.011014       208
# egypt           0.010572     17692
# lnschowengerdt  0.010208       137
# hallway         0.009275       110
# colombian       0.009274      3382
# involuntary     0.009043       173
# pnc             0.008372       443
# sfriedland      0.008148       154
# rudy            0.007882       205
#
# ------------------------------
# Topic name: topic_79.  P[topic_79] = 0.0107
#                    topic_79  doc_freq
# token
# nicosia            0.000042     13827
# neua               0.000040       329
# hostage            0.000039       740
# gyorgy             0.000039       135
# snyder             0.000038       453
# heichler           0.000038       246
# smun               0.000037       329
# jacqueline         0.000037       263
# internecine        0.000037       153
# thus               0.000036     50483
# crumbling          0.000036       109
# sindermann         0.000036       106
# gmc                0.000035       140
# reactions          0.000035      7812
# commercialization  0.000035       157
# mahe               0.000035       147
# zimbabwean         0.000034       242
# finalize           0.000034      1536
# curtains           0.000034       148
# toyo               0.000034       258

# %%
# Verify that the indices are equal.  The shapes shoudl be the same and the diff should be empty.
print meta.index.shape, lda.pr_doc.index.shape
print meta.index.diff(lda.pr_doc.index)
# Out:
# (1119239,) (1119648,)
# Index([], dtype='object')

# %%
lda.pr_doc_g_topic.T.groupby(meta.origclass)\
    .sum()\
    .loc[['UNCLASSIFIED', 'LIMITED OFFICIAL USE', 'CONFIDENTIAL', 'SECRET']]\
    .plot(kind='bar', figsize=(20, 10))

# %%
key_meta.loc[lda_index].msgfrom.unique()
# Out:
# array(['LIMA', 'ROME', 'ANKARA', 'NATO', 'CAIRO', 'MOSCOW', 'TEL AVIV',
#        'TEHRAN', 'BONN', 'BEIRUT', 'HONG KONG', 'SECSTATE WASHDC',
#        'USUN NEW YORK', 'NATO BRUSSELS', 'MANILA', 'ATHENS', 'PARIS',
#        'VIENNA', 'LONDON', 'GENEVA', 'JIDDA', 'OTTAWA', 'LISBON',
#        'NEW DELHI', 'BANGKOK', 'SEOUL', 'SANTIAGO', 'BELGRADE', 'MADRID',
#        'BRASILIA', 'MEXICO', 'BUENOS AIRES', 'TOKYO', 'WARSAW', 'JAKARTA',
#        'STOCKHOLM', 'LAGOS', 'CARACAS', 'BUCHAREST'], dtype=object)

# %%
lda.pr_doc_g_topic.groupby(key_meta.loc[lda_index].msgfrom)\
    .sum()\
    .T[meta.msgfrom.value_counts().index.tolist()[1:7]]\
    .plot(kind='bar', figsize=(20, 10))

# %%
lda.pr_doc_g_topic.groupby(key_meta.loc[lda_index].msgto)\
    .sum()\
    .T[meta.msgfrom.value_counts().index.tolist()[1:7]]\
    .plot(kind='bar', figsize=(20, 10))

# %% [markdown]
# ## Outlier detection

# %%
meta = meta.reindex(index=lda.pr_topic_g_doc.T.index)

# %%
meta = meta.dropna(how='all')

# %%
meta.shape
# Out:
# (1119239, 27)

# %%
len(dupes)
# Out:
# 409

# %%
meta.index[(meta.index != lda.pr_topic_g_doc.T.index)]
# Out:
# /Users/danielkrasner/anaconda/lib/python2.7/site-packages/pandas/core/index.py:619: DeprecationWarning: using a boolean instead of an integer will result in an error in the future
#   return arr_idx[key]
# '1973BONN06722'

# %%
y_var = 'origclass'
classes = meta[y_var].value_counts().index[:4]
print classes
# Out:
# Index([u'UNCLASSIFIED', u'LIMITED OFFICIAL USE', u'CONFIDENTIAL', u'SECRET'], dtype='object')

# %% [markdown]
# ##Build model test and train data

# %%
import re

# %%
#small cleaning for the "secret" meta variants
def clean_class(x):
    try:
        return re.sub(r'SECRET[\.\"\),S]', "SECRET", x)
    except TypeError:
        return x

# %%
meta.origclass = meta.origclass.apply(clean_class)
# Out:
# /Users/danielkrasner/anaconda/lib/python2.7/site-packages/pandas/core/generic.py:1615: SettingWithCopyWarning: A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_index,col_indexer] = value instead
#   self[name] = value

# %%
#look at what we have in terms of classification
meta.origclass.value_counts()[:4].plot(kind='bar', figsize=(15,8))

# %%
X = lda.pr_topic_g_doc.T.loc[meta.index]
Y = meta[y_var]
print X.shape, Y.shape
nan_rows = X.apply(lambda x: any([isnan(v) for v in x.values]), axis=1)
X = X.drop(nan_rows[nan_rows].index)
Y = Y.drop(nan_rows[nan_rows].index)
Y.name = 'Y'
print X.shape, Y.shape
# Out:
# (1119239, 80) (1119239,)
# (1119239, 80)
#  (1119239,)

# %%
def to_num(S, field='SECRET'):
    return S.apply(lambda x: 1 if x==field else 0)

# %%
###either build the mode (can take a while) or load it with cPickle
clf = RandomForestClassifier(n_estimators=400, min_samples_leaf=3, oob_score=True, n_jobs=-1)
clf.fit(X.values, to_num(Y))
print clf.oob_score_

# %%
print clf.oob_score_
# Out:
# 0.946074967009

# %%
Y.value_counts()
# Out:
# 0    1059207
# 1      60032
# dtype: int64

# %%
###consider saving the model
import cPickle
model_name = 'RF_secret_class'
with open(os.path.join(PROCESSED, model_name+'.pkl'), 'wb') as m:
          cPickle.dump(clf, m)

# %%
#if necessary load the model
import cPickle
model_name = 'RF_secret_class'
with open(os.path.join(PROCESSED, model_name+'.pkl'), 'r') as m:
          clf = cPickle.load(m)

# %%
Yhat = pd.DataFrame(clf.predict_proba(X.values), columns = [0,1], index=X.index)

# %%
Yhat = Yhat.join(to_num(Y))

# %%
##save it since it takes a while to load the models
Yhat.to_csv(os.path.join(PROCESSED, 'cables_pred.csv'))

# %%
###read it in 
Yhat = pd.read_csv(os.path.join(PROCESSED, 'cables_pred.csv'), index_col=0)

# %%
Yhat['1'].head()
# Out:
# doc_id
# 1975NATO00549      0.400238
# 1973BONN06722      0.168350
# 1973ATHENS08224    0.323836
# 1974SOFIA00298     0.000000
# 1975FRANKF02095    0.003339
# Name: 1, dtype: float64

# %% [markdown]
# ### do a bit of ROC analysis

# %%
from sklearn.metrics import roc_curve, auc

# %%
# Compute ROC curve and area the curve
fpr, tpr, thresholds = roc_curve(Yhat['Y'], Yhat['1'])
roc_auc = auc(fpr, tpr)
print("Area under the ROC curve : %f" % roc_auc)
# Out:
# Area under the ROC curve : 0.940687

# %%
# Plot ROC curve
plt.clf()
plt.figure(figsize=(15,8))
plt.plot(fpr, tpr, label='ROC curve (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], 'k--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.0])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic example')
plt.legend(loc="lower right")
plt.show()

# %%
### determine the optimal threshold
def opt_thresh(fpr, tpr, thresholds):
    """
    returns optimized roc threshold, i.e. the one which corresponds to
    min dist([fpr, tpr], [0,1])
    """
    roc = pd.DataFrame({'fpr': fpr, 'tpr': tpr})
    min_index = roc.apply(_roc_dist, axis=1).idxmin()
    return thresholds[min_index]
def _roc_dist(point):
    return dist(point, np.array([0, 1]))

# %%
thresh = opt_thresh(fpr, tpr, thresholds)

# %%
def get_class_stats(Y_test, Y_hat):
    """
    Returns basic classifier rate stats.
    """
    tpr = ((Y_hat==1)&(Y_test==1)).sum()/float((Y_hat==1).sum())
    fpr = ((Y_hat==1)&(Y_test==0)).sum()/float((Y_hat==1).sum())
    tnr = ((Y_hat==0)&(Y_test==0)).sum()/float((Y_hat==0).sum())
    fnr = ((Y_hat==0)&(Y_test==1)).sum()/float((Y_hat==0).sum())
    trues = (((Y_hat==1)&(Y_test==1)).sum()
             + ((Y_hat==0)&(Y_test==0)).sum())/float(Y_test.shape[0])
    return {'tpr': tpr, 'fpr': fpr, 'tnr': tnr, 'fnr': fnr, 'per_true': trues}

# %%
Yhat['Yhat_opt'] = Yhat['1'].apply(lambda x: 1 if x>thresh*3 else 0)

# %%
get_class_stats(Yhat['Y'], Yhat['Yhat_opt'])
# Out:
# {'fnr': 0.05023293025725474,
#  'fpr': 0.06654300950614421,
#  'per_true': 0.94970421867000698,
#  'tnr': 0.94976706974274527,
#  'tpr': 0.93345699049385578}

# %%
((Yhat['Y']==1)&(Yhat['Yhat_opt']==1)).sum()/float((Yhat['Yhat_opt']==1).sum())
# Out:
# 0.93345699049385578

# %%
missclass = (Yhat['Y'] != Yhat['Yhat_opt'])

# %%
missclass_secret = ((Yhat['Y']==0)&(Yhat['Yhat_opt']==1))

# %%
missclass_secret.sum()
# Out:
# 287

# %%
missclass_secret_scores = Yhat[missclass_secret]['1'].copy()

# %%
missclass_secret_scores.sort(ascending=False)

# %%
missclass_secret_scores.shape
# Out:
# (287,)

# %%
##look at missclassified secret messages 

field = 'msgfrom'
meta[missclass_secret][field].value_counts().plot(kind='bar', figsize=(20,15),
                                                   title='Missclassified Secret Cables by %s'%field.upper())
plt.savefig(os.path.join(PLOTS, 'missclass_secret%s.png'%cutoff))

# %%
#dumb the doc_id's to disk
with open(os.path.join(PROCESSED, 'missclass_secret.txt'), 'w') as f:
    f.writelines('\n'.join(missclass_secret_scores.index))

# %%
missclass_meta = meta.loc[Yhat[missclass].index]

# %%
missclass_meta.shape
# Out:
# (56293, 27)

# %%
cutoff = 50
field = 'msgfrom'
missclass_meta[field].value_counts()[:cutoff].plot(kind='bar', figsize=(20,15),
                                                   title='Missclassified Cables by %s'%field.upper())
plt.savefig(os.path.join(PLOTS, 'missclass_top%s.png'%cutoff))

# %%
cutoff = 50
field = 'msgfrom'
missclass_meta[field].value_counts()[:cutoff].plot(kind='bar', figsize=(20,15),
                                                   title='Missclassified Cables by %s'%field.upper())
plt.savefig(os.path.join(PLOTS, 'missclass_top%s.png'%cutoff))

# %%
miss_class_per = missclass_meta[field].value_counts()/meta[field].value_counts()

# %%
miss_class_per.sort(ascending=False)

# %%
#look at some top name candidates
miss_class_per_top=miss_class_per[missclass_meta[field].value_counts()[:cutoff].index]
miss_class_per_top.sort(ascending=False)
miss_class_per_top.plot(kind='bar', figsize=(20,15),title='Missclassified Percent of Cables by %s'%field.upper())
plt.savefig(os.path.join(PLOTS, 'missclass_top_per%s.png'%cutoff))

# %%
name = 'MADRID'
field = 'msgfrom'
missclass_name_secret = missclass_meta[missclass_meta[field]==name]
#with open(os.path.join(PROCESSED, 'missclass_%s.txt'%name), 'w') as f:
#    f.writelines('\n'.join(missclass_name))

# %%
##secret vs non
secret = (Yhat['Yhat_opt']==1)
missclass_secret = ((Yhat['Y']==0)&(Yhat['Yhat_opt']==1))
nonsecret = (Yhat['Yhat_opt']==0)
missclass_nonsecret = ((Yhat['Y']==1)&(Yhat['Yhat_opt']==0))

# %%
secret_scores = Yhat[missclass_secret]['1'].copy()
secret_scores.sort(ascending=False)
nonsecret_scores = Yhat[missclass_nonsecret]['0'].copy()
nonsecret_scores.sort(ascending=False)

# %%
secret_scores.describe(), nonsecret_scores.describe()
# Out:
# (count    287.000000
# mean       0.469567
# std        0.041653
# min        0.422327
# 25%        0.439353
# 50%        0.459419
# 75%        0.488787
# max        0.649320
# Name: 1, dtype: float64,
#  count    56006.000000
# mean         0.749525
# std          0.102340
# min          0.577995
# 25%          0.676164
# 50%          0.718395
# 75%          0.801354
# max          0.997368
# Name: 0, dtype: float64)

# %%
nonsecret_scores.head()
# Out:
# doc_id
# 1973PHNOM14345     0.997368
# 1975BONN14230      0.997360
# 1975STATE090498    0.997060
# 1976BELGRA00154    0.996250
# 1974ATHENS04724    0.996250
# Name: 0, dtype: float64

# %%
###look at a particular embassy
name = 'SALT TALKS'
field = 'msgfrom'

nonsecret_scores_byname = nonsecret_scores.loc[meta.loc[nonsecret_scores.index][field]==name]

with open(os.path.join(PROCESSED, 'missclass_nonsecret_%s.txt'%name), 'w') as f:
    f.writelines('\n'.join(nonsecret_scores_byname.index))

# %%
###look at a particular embassy
name = 'SALT TALKS'
field = 'msgfrom'

secret_scores_byname = secret_scores.loc[meta.loc[secret_scores.index][field]==name]

with open(os.path.join(PROCESSED, 'missclass_secret_%s.txt'%name), 'w') as f:
    f.writelines('\n'.join(secret_scores_byname.index))

# %%
nonsecret_scores

# %%
missclass_meta_secret = missclass_meta[secret]
missclass_meta_nonsecret = missclass_meta[nonsecret]

# %%
missclass_meta_secret.shape, missclass_meta_nonsecret.shape
# Out:
# ((287, 27), (56006, 27))

# %%
###look at those originally labelled unclassified
missclass_unclas = (missclass_meta.loc[missclass_meta_secret.index].origclass=='UNCLASSIFIED')

# %%
missclass_meta_secret.loc[missclass_unclas].index

# %%
missclass_unclas_scores = Yhat.loc[missclass_meta_secret.loc[missclass_unclas].index]['1'].copy()
missclass_unclas_scores.sort(ascending=False)

# %%
with open(os.path.join(PROCESSED, 'missclass_secret_unclass.txt'), 'w') as f:
    f.writelines('\n'.join(missclass_unclas_scores.index))

# %%
missclass_unclas_scores
# Out:
# doc_id
# 1976LONDON09802    0.649320
# 1974STATE167356    0.637187
# 1976IAEAV03447     0.609797
# 1974STATE085546    0.594413
# 1975ANKARA03552    0.568628
# 1976STATE104170    0.560892
# 1974ADDIS09835     0.557056
# 1975LONDON02404    0.553824
# 1976STATE105495    0.536388
# 1974OTTAWA00112    0.530044
# 1974CAIRO06479     0.522512
# 1976STATE173164    0.520256
# 1973STATE237001    0.515633
# 1973BONN12778      0.513620
# 1976MANAMA00559    0.513566
# 1974MANILA13727    0.506035
# 1974ATO03410       0.503094
# 1974MADRID01846    0.500157
# 1976STATE116766    0.498717
# 1976LONDON20170    0.496871
# 1973IAEAV06742     0.495698
# 1975TEHRAN03209    0.490170
# 1976STATE232583    0.486207
# 1976LAGOS02596     0.485871
# 1974ECBRU01725     0.482379
# 1976STATE261341    0.479409
# 1975ROME14403      0.479187
# 1976USUNN00273     0.478409
# 1974PARIS09724     0.477803
# 1976QUITO07748     0.476888
# 1975STATE154754    0.475342
# 1976TOKYO17024     0.471676
# 1974STATE205985    0.467066
# 1974USUNN02334     0.466942
# 1976DAMASC06107    0.465990
# 1975MONTRE01843    0.465480
# 1974MEXICO09653    0.464904
# 1976STATE242014    0.461025
# 1974USUNN02567     0.460824
# 1974LISBON00476    0.459885
# 1975STATE010046    0.459419
# 1975TANANA01957    0.458686
# 1976CARACA12274    0.456802
# 1974TELAV07212     0.456438
# 1975STATE271843    0.456022
# 1973STATE057816    0.453876
# 1975KINSHA08518    0.451961
# 1973STATE056390    0.451166
# 1976STATE119194    0.448778
# 1975STATE062849    0.446407
# 1975KINGST02711    0.445698
# 1975USBERL01411    0.445556
# 1975VIENNA08212    0.445486
# 1976BRASIL03491    0.444458
# 1976LISBON02740    0.442149
# 1976MANAMA01101    0.441753
# 1976STATE045814    0.440810
# 1973STATE118500    0.440497
# 1975ROME06684      0.438845
# 1976QUITO08690     0.438824
# 1974TEGUCI01762    0.437556
# 1975USUNN01683     0.435755
# 1973TELAV03673     0.433295
# 1976STATE185070    0.432965
# 1973USUNN02785     0.431691
# 1975LIBREV01365    0.430772
# 1975VIENNA08269    0.428123
# 1975SANTIA02153    0.426962
# 1975STATE238259    0.426265
# 1976STATE017183    0.424087
# 1974BUCHAR03683    0.423996
# 1974ECBRU00252     0.422327
# Name: 1, Length: 72, dtype: float64
